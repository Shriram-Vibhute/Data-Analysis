# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips['tip_pct'] = (tips['tip'] / tips['total_bill'])
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pct
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.146808

# %% [markdown]
# <div style="color:white;display:fill;border-radius:5px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#2ae4f5'>1 |</span></b> Scatter Plots </b></p>
# </div>
#
# 📌 `Note` - Scatter plots are used to analyze relationships between (numerical-numerical) columns, while also incorporating categorical columns through parameters such as `hue`, `size`, and `style`.

# %%
plt.figure(figsize=(15, 7))
sns.scatterplot(
    x = tips['total_bill'],
    y = tips['tip'],
    hue = tips['sex'],
    size = tips['size'],
    style = tips['day']
)
plt.legend(loc='upper left', fontsize='small', title='Legend Title', title_fontsize='medium')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;display:fill;border-radius:5px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#2ae4f5'>2 |</span></b> Line Plots </b></p>
# </div>
#
# 📌 `Note` - Line plots are used to analyze relationships between (numerical-numerical) columns, while also incorporating categorical columns through parameters such as `hue`.

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
plt.figure(figsize = (15, 7))
sns.lineplot(
    x=titanic['age'],  
    y=titanic['fare'],  
    hue=titanic['survived']
)
plt.ylim(0, 300)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;display:fill;border-radius:5px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#2ae4f5'>3 |</span></b> Strip Plots </b></p>
# </div>
#
# > A strip plot is a type of data visualization that displays individual data points along a single axis, often used for visualizing the distribution of a variable across different categories.
# > 1. **Structure**: In a strip plot, data points are plotted along one axis (usually the y-axis), with categories represented along the other (often the x-axis). Points can be "jittered" to avoid overlap and show the density of data.<br><br>
# > 2. **Usage**: It’s particularly useful for visualizing small to medium-sized datasets, allowing for quick identification of distribution patterns, clusters, and outliers.<br><br>
# > 3. **Comparison**: Strip plots are often used in conjunction with other plots (like box plots) to provide a detailed view of data distribution within each category.<br><br>
# > 4. **Customization**: You can adjust point transparency, size, and color to enhance clarity and highlight specific groups or trends.<br><br>
# > 5. **Limitations**: While informative, strip plots can become cluttered with larger datasets, making it harder to discern individual points.

# %%
sns.catplot(
    x = tips['day'],
    y = tips['total_bill'],
    kind = 'strip',
    hue = tips['sex'],
    height=7,      # height of the plot
    aspect=2.14,    # width/height ratio
    jitter = 0.08
)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;display:fill;border-radius:5px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#2ae4f5'>4 |</span></b> Swarm Plots </b></p>
# </div>
#
# > A swarm plot is an enhanced version of a strip plot, designed to display individual data points while avoiding overlap. Here are some important aspects of swarm plots:<br><br>
# > 1. **Structure**: Similar to strip plots, swarm plots display data points along one axis (usually the y-axis) for different categories on the other (x-axis). However, swarm plots use a "swarming" algorithm to arrange points in a way that minimizes overlap.<br><br>
# > 2. **Distribution Visualization**: Swarm plots effectively show the distribution of data points and can reveal patterns, clusters, and outliers while maintaining the individual data visibility.<br><br>
# > 3. **Comparison with Strip Plots**: While both plots show data points, swarm plots provide a clearer representation, especially for larger datasets, because they prevent points from stacking on top of each other.<br><br>
# > 4. **Customization**: You can customize colors, shapes, and sizes of the points to convey additional information, such as grouping or categorical variables.<br><br>
# > 5. **Use Cases**: Swarm plots are commonly used in fields like biology and social sciences to visualize experimental data, allowing for easy comparisons across different groups.<br><br>
# > 6. **Limitations**: Although they improve clarity compared to strip plots, swarm plots can still become crowded with very large datasets, and the arrangement might be less intuitive in some cases.

# %%
sns.catplot(
    x = tips['day'],
    y = tips['total_bill'],
    kind = 'swarm',
    hue = tips['sex'],
    height=7,      # height of the plot
    aspect=2.14,    # width/height ratio
)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;display:fill;border-radius:5px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#2ae4f5'>5 |</span></b> Box Plots </b></p>
# </div>
#
# 📌 `Note` - Box Plots are used to detect the outliers in a data, also you can compaire the distribution along various categories.

# %%
sns.catplot(
    y = tips['total_bill'],
    x = tips['day'],
    kind = 'box',
    hue = tips['sex'],
    height = 7,
    aspect = 2.14,
)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;display:fill;border-radius:5px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#2ae4f5'>6 |</span></b> Violin Plots </b></p>
# </div>
#
# 📌 `Note` - Violin plots combine box plots and density plots to provide a comprehensive view of the distribution of a variable across multiple categories. They display the data’s probability density on each side, allowing for visual comparisons of the distribution shape, central tendency, and spread within different groups. In multivariate analysis, violin plots are particularly useful for understanding the relationships and variations across multiple dimensions simultaneously.

# %%
sns.catplot(
    x = tips['day'],
    y = tips['total_bill'],
    kind = 'violin',
    hue = tips['sex'],
    height = 7,
    aspect = 2.14,
    split = True
)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;display:fill;border-radius:5px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#2ae4f5'>7 |</span></b> Point Plots </b></p>
# </div>
#
# 📌 `Note` - Point plots are used to display the relationship between two variables, where one variable is represented on the x-axis and the other on the y-axis, with individual data points plotted as dots. They are effective for visualizing summary statistics, like means or medians, across different categories, often with error bars to indicate variability.

# %%
sns.catplot(
    x = tips['day'],
    y = tips['total_bill'],
    kind = 'point',
    height = 7,
    aspect = 2.14,
    # hue = tips['sex'],
    # estimator = np.median
)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;display:fill;border-radius:5px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#2ae4f5'>8 |</span></b> Bar Plots </b></p>
# </div>

# %%
sns.catplot(
    x = tips['day'],
    y = tips['total_bill'],
    kind = 'bar',
    hue = tips['sex'],
    height = 7,
    aspect = 2.14,
    # estimator = np.median
)
plt.show()

# %% [markdown]
# 🚧 Note - The difference in outputs between seaborn and matplotlib arises from how the two libraries handle data aggregation. Seaborn's `catplot` function automatically computes the mean for each category when using the 'bar' kind, which results in a clear representation of the average values for each category on the y-axis. In contrast, when using matplotlib's `bar` function, you must manually compute the means for each category. If the data is not aggregated correctly before plotting with matplotlib, it can lead to unexpected or 'weird' results. Therefore, it's essential to ensure that the data is properly summarized before creating a bar plot with matplotlib.

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;display:fill;border-radius:5px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#2ae4f5'>9 |</span></b> Count Plots </b></p>
# </div>

# %%
sns.catplot(
    x = tips['day'],
    kind = 'count',
    hue = tips['sex'],
    height = 7,
    aspect = 2.14,
)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;display:fill;border-radius:5px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#2ae4f5'>10 |</span></b> Heatmaps </b></p>
# </div>

# %%
pvt = titanic.pivot_table(
    index = 'embark_town',
    columns = 'class',
    values = 'fare',
    aggfunc = 'count',
    observed = True
)

plt.figure(figsize=(15, 7))
sns.heatmap(pvt, annot=True, fmt="d")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;display:fill;border-radius:5px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#2ae4f5'>11 |</span></b> Clustermaps </b></p>
# </div>

# %%
sns.clustermap(pvt, annot=True, fmt="d", figsize=(15, 10))
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;display:fill;border-radius:5px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#2ae4f5'>12 |</span></b> Joint Scatter Plot </b></p>
# </div>

# %%
sns.jointplot(
    x = tips['total_bill'],
    y = tips['tip'],
    hue = tips['sex'],
    style = tips['smoker'],
    size = tips['size']
)
plt.legend(loc='upper left', fontsize='small', title='Legend', title_fontsize='small')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;display:fill;border-radius:5px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#2ae4f5'>13 |</span></b> Joint HexBin Plots </b></p>
# </div>

# %%
sns.jointplot(
    x = tips['total_bill'],
    y = tips['tip'],
    kind = 'hex'
)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;display:fill;border-radius:5px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#2ae4f5'>14 |</span></b> Joint KDE Plots </b></p>
# </div>

# %%
sns.jointplot(
    x = tips['total_bill'],
    y = tips['tip'],
    kind = 'kde',
    fill = True
)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;display:fill;border-radius:5px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#2ae4f5'>15 |</span></b> Joint Reg Plots </b></p>
# </div>

# %%
sns.jointplot(
    x = tips['total_bill'],
    y = tips['tip'],
    kind = 'reg'
)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;display:fill;border-radius:5px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#2ae4f5'>16 |</span></b> Facet Grids </b></p>
# </div>

# %%
g = sns.FacetGrid(tips, col="day",  row="sex", hue='smoker', legend_out=True)
g.map(sns.scatterplot, "total_bill", "tip")
plt.show()

# %%
g = sns.FacetGrid(tips, col="size", height=2.5, col_wrap=3)
g.map(sns.histplot, "total_bill")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;display:fill;border-radius:5px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#2ae4f5'>17 |</span></b> Pair Plots </b></p>
# </div>

# %%
sns.pairplot(tips, hue = 'sex')
plt.show()

# %% [markdown]
# ---
