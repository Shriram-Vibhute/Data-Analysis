# %% [markdown]
# ## Univariate Analysis using Matplotlib & Seaborn
# - Bar Plots
# - Pie Charts
# - Histograms
# - Distribution Plots
# - Box Plots
# - Violin Plots
# - Strip Plots
# - CDF Plots
# - Quantile Plots
# - Rug Plots

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ---

# %% [markdown]
# ### Bar Plots
# 📌`Note` - Bar plots are used for count analysis in univariate analysis

# %%
plt.figure(figsize = (15, 7))
plt.bar(df['alive'].unique(), df['alive'].value_counts())
plt.show()

# %%
plt.figure(figsize=(15, 7))
sns.barplot(x = df['who'].unique(), y = df['who'].value_counts())
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Pie Charts

# %%
plt.pie(df['alive'].value_counts(), autopct='%.2f')
plt.show()

# %% [markdown]
# 📌 `Note` - Seaborn’s API is designed to focus on statistical applications and provides improved defaults for many matplotlib functionalities, but it does not include pie charts.<br><br>
# 📌 `Seaborn CatPlots` - Seaborn catplot (kind='count') change bar chart to pie chart

# %%
sns.catplot(data = df['sex'], kind='count', height=5)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Histograms

# %%
plt.figure(figsize = (15, 7))
plt.hist(df['age'], bins=20)
plt.show()

# %%
plt.figure(figsize = (15, 7))
sns.histplot(df['age'], kde=True)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Distribution Plots
# 📌 `Important` - Density axis is a Kernal Density Function / PDF

# %%
sns.displot(df['age'], kind='kde')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Box Plots
# 📌 `Note` - Box plots are generally used to detect the outliers

# %%
sns.boxplot(df['age'])
plt.show()

# %% [markdown]
# 📌 `boxenplots` - Used to analysis boxplots of various columns side by side

# %%
sns.boxenplot([df['age'], df['fare']])
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Violin Plots
# 📌 `Note` - Its a combination of `box plots` and `kde plot`

# %%
sns.violinplot(df['age'])
plt.show()

# %% [markdown]
# 📌 `Note` - Though its a multiplevariate Analysis

# %%
sns.catplot(x = df['class'], y = df['fare'], kind='violin', hue=df['sex'], split=True)

# %% [markdown]
# ---

# %% [markdown]
# ### Strip Plots

# %%
sns.stripplot(df['age'])
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Rug Plots

# %%
sns.rugplot(df['age'])
plt.show()
